# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import ot

from dtmrpy import DT_GMM

from time import time

device='cuda'

# %%
df = pd.read_pickle("data_files/dtmri_dataframe_11_2.pkl")

# df['labels']= pd.read_csv("C:/Users/micha/OneDrive - Florida State University/Projects/DTMRI/PTSD_CAPS_MPSS.csv")['da_ptsd_current'].to_numpy()

df = df[df['labels']!='#NULL!']
# df = df.sort_values('labels',ignore_index=True)

df
# Out:
#        sid                 Cingulum_Frontal_Parahippocampal_L  \
# 0     6610  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162DB1C...
# 1     6753                                                NaN
# 2     6824  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162ECEE...
# 3     7373  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162ECEE...
# 5     7470  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162ECEF...
# ..     ...                                                ...
# 167  20548  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162ECFF...
# 169  20568  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162ECFF...
# 170  20594  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162ECFF...
# 172  20683  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162ECFF...
# 173  20690  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162ECFF...
#
#                     Cingulum_Frontal_Parahippocampal_R  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162ECFF...
# 1                                                  NaN
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162ECFF...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162ECFF...
# 5    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162ECFF...
# ..                                                 ...
# 167  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162EEFF...
# 169  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162EEFF...
# 170  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162EEFF...
# 172  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162EEFF...
# 173  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162EF00...
#
#                            Cingulum_Frontal_Parietal_L  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162EF00...
# 1                                                  NaN
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162EF00...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162EF00...
# 5    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162EF00...
# ..                                                 ...
# 167  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162EF06...
# 169  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162EF06...
# 170  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162EF06...
# 172  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162EF06...
# 173  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162EF06...
#
#                            Cingulum_Frontal_Parietal_R  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162EF06...
# 1                                                  NaN
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162EF06...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162EF06...
# 5    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162EF07...
# ..                                                 ...
# 167  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162F6F5...
# 169  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162F6F5...
# 170  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162F6F5...
# 172  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162F6F5...
# 173  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162F6F5...
#
#                             Cingulum_Parahippocampal_L  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162F6F5...
# 1                                                  NaN
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162F6F5...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162F6F5...
# 5    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162F6F5...
# ..                                                 ...
# 167  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162F6FC...
# 169  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162F6FC...
# 170  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162F6FC...
# 172  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162F6FC...
# 173  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162F6FC...
#
#                             Cingulum_Parahippocampal_R  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162F6FC...
# 1                                                  NaN
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162F6FC...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162F6FC...
# 5    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162F6FC...
# ..                                                 ...
# 167  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162F702...
# 169  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162F702...
# 170  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162F702...
# 172  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162F702...
# 173  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162F702...
#
#                    Cingulum_Parahippocampal_Parietal_L  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162F702...
# 1                                                  NaN
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162F702...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162F702...
# 5    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162F702...
# ..                                                 ...
# 167  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162FA00...
# 169  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162FA00...
# 170  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162FA00...
# 172  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162FA00...
# 173  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162FA00...
#
#                    Cingulum_Parahippocampal_Parietal_R  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162FA00...
# 1                                                  NaN
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162FA00...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162FA00...
# 5    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162FA00...
# ..                                                 ...
# 167  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162FA06...
# 169  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162FA06...
# 170  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162FA07...
# 172  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162FA07...
# 173  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162FA07...
#
#                                Cingulum_Parolfactory_L  ...  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162FA07...  ...
# 1                                                  NaN  ...
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162FA07...  ...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162FA07...  ...
# 5    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162FA07...  ...
# ..                                                 ...  ...
# 167  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162FEFE...  ...
# 169  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162FEFE...  ...
# 170  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162FEFE...  ...
# 172  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162FEFE...  ...
# 173  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162FEFE...  ...
#
#                                               Fornix_R  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A16E...
# 1                                                  NaN
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A16E...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A16E...
# 5    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A16F...
# ..                                                 ...
# 167  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A174...
# 169  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A174...
# 170  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A174...
# 172  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A174...
# 173  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A174...
#
#                    Superior_Longitudinal_Fasciculus1_L  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A174...
# 1                                                  NaN
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A174...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A174...
# 5    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A174...
# ..                                                 ...
# 167  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A473...
# 169  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A473...
# 170  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A473...
# 172  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A473...
# 173  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A473...
#
#                    Superior_Longitudinal_Fasciculus1_R  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A473...
# 1                                                  NaN
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A473...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A473...
# 5    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A473...
# ..                                                 ...
# 167  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A479...
# 169  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A479...
# 170  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A479...
# 172  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A479...
# 173  <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A479...
#
#                    Superior_Longitudinal_Fasciculus2_L  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A479...
# 1                                                  NaN
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A479...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A479...
# 5    <dtmrpy.dtmrpy.DT_GMM object at 0x00000162A479...
# ..                                                 ...
# 167  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016304E8...
# 169  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016304E9...
# 170  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016304E9...
# 172  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016304E9...
# 173  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016304E9...
#
#                    Superior_Longitudinal_Fasciculus2_R  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x0000016304E9...
# 1                                                  NaN
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x0000016304E9...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x0000016304E9...
# 5    <dtmrpy.dtmrpy.DT_GMM object at 0x0000016304E9...
# ..                                                 ...
# 167  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016304EF...
# 169  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016304EF...
# 170  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016304EF...
# 172  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016304EF...
# 173  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016304F0...
#
#                    Superior_Longitudinal_Fasciculus3_L  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x0000016304F0...
# 1                                                  NaN
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x0000016304F0...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x0000016304F0...
# 5    <dtmrpy.dtmrpy.DT_GMM object at 0x0000016304F0...
# ..                                                 ...
# 167  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016310D2...
# 169  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016310D2...
# 170  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016310D2...
# 172  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016310D2...
# 173  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016310D2...
#
#                    Superior_Longitudinal_Fasciculus3_R  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x0000016310D2...
# 1                                                  NaN
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x0000016310D2...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x0000016310D2...
# 5    <dtmrpy.dtmrpy.DT_GMM object at 0x0000016310D3...
# ..                                                 ...
# 167  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016310D8...
# 169  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016310D8...
# 170  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016310D8...
# 172  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016310D8...
# 173  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016310D8...
#
#                                  Uncinate_Fasciculus_L  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x0000016310D8...
# 1                                                  NaN
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x0000016310D8...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x0000016310D8...
# 5    <dtmrpy.dtmrpy.DT_GMM object at 0x0000016310D8...
# ..                                                 ...
# 167  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016310DF...
# 169  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016310DF...
# 170  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016310DF...
# 172  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016310DF...
# 173  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016310DF...
#
#                                  Uncinate_Fasciculus_R labels
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x0000016310DF...      0
# 1                                                  NaN      0
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x0000016310DF...      1
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x0000016310DF...      0
# 5    <dtmrpy.dtmrpy.DT_GMM object at 0x0000016310DF...      0
# ..                                                 ...    ...
# 167  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016318CE...      1
# 169  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016318CE...      0
# 170  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016318CE...      0
# 172  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016318CE...      0
# 173  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016318CE...      1
#
# [140 rows x 26 columns]

# %%
plt.figure().add_subplot(projection='3d')
df.at[2,'Cingulum_Frontal_Parahippocampal_R'].plot()
plt.show()

# %%
from scipy.spatial.distance import cdist

import geomstats
from geomstats.geometry.spd_matrices import SPDMatrices, SPDBuresWassersteinMetric

#for bures log map
from geomstats.geometry.symmetric_matrices import SymmetricMatrices
from geomstats.geometry.matrices import Matrices

space = SPDMatrices(3)
space.equip_with_metric(SPDBuresWassersteinMetric)



def bures_distance_matrix(Sigma_x,Sigma_y):
    Ux,Sx,Vx = torch.linalg.svd(Sigma_x)
    Sigma_x_sqrt = torch.matmul(torch.matmul(Ux,torch.diag_embed(torch.sqrt(Sx))),Vx)
    
    cross_term = torch.matmul(torch.matmul(Sigma_x_sqrt, Sigma_y.unsqueeze(1)),Sigma_x_sqrt.unsqueeze(0))
    Uc,Sc,Vc = torch.linalg.svd(cross_term)
    sqrt_cross_term = torch.matmul(torch.matmul(Uc,torch.diag_embed(torch.sqrt(Sc))),Vc)

    return torch.einsum('ijkk -> ij', Sigma_x.unsqueeze(0) + Sigma_y.unsqueeze(1) - 2*sqrt_cross_term).T #the transpose here should be fixed


def wasserstein_type_distance(mu0,mu1,reg=1,reg_m=1):
    (weights0,means0,sigma0)=(mu0.weights_,mu0.means_,torch.tensor(mu0.covariances_).to(device))
    (weights1,means1,sigma1)=(mu1.weights_,mu1.means_,torch.tensor(mu1.covariances_).to(device))

    M = cdist(means0,means1)**2 + bures_distance_matrix(sigma0,sigma1).cpu().numpy()
    
    # return M,ot.unbalanced.sinkhorn_unbalanced(weights0.reshape(-1),weights1.reshape(-1),M,reg=reg,reg_m=reg_m)
    a = weights0.reshape(-1)/np.sum(weights0)
    b = weights1.reshape(-1)/np.sum(weights1)
    return M, ot.emd(a,b,M)


def my_symmetric_sqrt(M, p):
    U,S,V = np.linalg.svd(M)
    return U@np.diag(S**p)@V
    

def my_bures_log(point, base_point):
        """Compute the Bures-Wasserstein logarithm map.

        Compute the Riemannian logarithm at point base_point,
        of point wrt the Bures-Wasserstein metric.
        This gives a tangent vector at point base_point.

        Parameters
        ----------
        point : array-like, shape=[..., n, n]
            Point.
        base_point : array-like, shape=[..., n, n]
            Base point.

        Returns
        -------
        log : array-like, shape=[..., n, n]
            Riemannian logarithm.
        """        
        # compute B^1/2(B^-1/2 A B^-1/2)B^-1/2 instead of sqrtm(AB^-1)
        sqrt_bp = my_symmetric_sqrt(base_point, 0.5)
        inv_sqrt_bp = my_symmetric_sqrt(base_point, -0.5)
        pdt = my_symmetric_sqrt(Matrices.mul(sqrt_bp, point, sqrt_bp),.5)
        sqrt_product = Matrices.mul(sqrt_bp, pdt, inv_sqrt_bp)
        transp_sqrt_product = Matrices.transpose(sqrt_product)
        return sqrt_product + transp_sqrt_product - 2 * base_point


def means_update(barycenter, measure_list, Pi_list):
        
    return np.mean(np.array([measure_list[i].means_.T@Pi_list[i].T@np.diag(1/barycenter.weights_.reshape(-1)) for i in range(len(measure_list))]),0).T

    
def covariance_update(space, barycenter, measure_list, Pi_list):
    
    Sigma0=space.projection(barycenter.covariances_)
    Sigma0_update = np.zeros_like(Sigma0)
    num_measures=len(measure_list)

    for p, measure in enumerate(measure_list):

        Pi=Pi_list[p]
        
        Sigma1=space.projection(measure.covariances_)

        for i in range(Sigma0.shape[0]):
            sigma0=Sigma0[i]
            ind = np.where(Pi[i]>0)[0]
            Sigma1_log = np.array([my_bures_log(sigma1,sigma0) for sigma1 in Sigma1[ind]])

            #Update Covariance
            temp=np.zeros((3,3))
            w_i=sum(Pi[i])
            for j in range(len(ind)):
                temp += Pi[i,ind[j]]*Sigma1_log[j]

            Sigma0_update[i] += space.metric.exp(temp/w_i,sigma0)/num_measures
            
    return Sigma0_update
    
    
def free_support_barycenter_update(measure_list, barycenter=None, N=200):
    
    if barycenter==None:
        # initialize weights
        # May need to change initial weights
        init_weights = np.ones((N,1))/N
        init_means = np.zeros(3)+np.random.normal(size=(N,3))
        # init_means = np.mean(measure_list[0].means_,0)+np.random.normal(size=(N,3))*np.std(measure_list[0].means_,0)
        init_covariances = SPDMatrices(3).random_point(N)
        barycenter = DT_GMM(weights=init_weights, means=init_means, covariances=init_covariances)
        # barycenter=measure_list[0]
        
    else:
    
        Pi_list = [wasserstein_type_distance(barycenter, measure)[1] for measure in measure_list]
        barycenter.means_ = means_update(barycenter, measure_list, Pi_list)
        barycenter.covariances_ = covariance_update(space, barycenter, measure_list, Pi_list) 
    
    return barycenter



###Sinkhorn versions
def sinkhorn_type_distance(mu0,mu1,reg=1,reg_m=1):
    (weights0,means0,sigma0)=(mu0.weights_,mu0.means_,torch.tensor(mu0.covariances_).to(device))
    (weights1,means1,sigma1)=(mu1.weights_,mu1.means_,torch.tensor(mu1.covariances_).to(device))

    M = cdist(means0,means1)**2 + bures_distance_matrix(sigma0,sigma1).cpu().numpy()
    
    # return M,ot.unbalanced.sinkhorn_unbalanced(weights0.reshape(-1),weights1.reshape(-1),M,reg=reg,reg_m=reg_m)
    a = weights0.reshape(-1)/np.sum(weights0)
    b = weights1.reshape(-1)/np.sum(weights1)
    return M, ot.sinkhorn(a,b,M, reg=0.1)


def free_support_sinkhorn_barycenter_update(measure_list, barycenter=None, N=200):
    
    if barycenter==None:
        # initialize weights
        # May need to change initial weights
        init_weights = np.ones((N,1))/N
        init_means = np.zeros(3)+np.random.normal(size=(N,3))
        # init_means = np.mean(measure_list[0].means_,0)+np.random.normal(size=(N,3))*np.std(measure_list[0].means_,0)
        init_covariances = SPDMatrices(3).random_point(N)
        barycenter = DT_GMM(weights=init_weights, means=init_means, covariances=init_covariances)
        # barycenter=measure_list[0]
        
    else:
    
        Pi_list = [sinkhorn_type_distance(barycenter, measure, reg=0.1)[1] for measure in measure_list]
        barycenter.means_ = means_update(barycenter, measure_list, Pi_list)
        barycenter.covariances_ = covariance_update(space, barycenter, measure_list, Pi_list) 
    
    return barycenter
# Out:
# INFO: Using numpy backend

# %%
mu0=df['Cingulum_Frontal_Parahippocampal_R'][2]
mu1=df['Cingulum_Frontal_Parahippocampal_R'][3]

# %%
M,Pi = wasserstein_type_distance(mu0,mu1)
M2,Pi2 = sinkhorn_type_distance(mu0,mu1)
# Out:
# C:\Users\micha\anaconda3\envs\gpu_compute_env\Lib\site-packages\ot\bregman.py:503: RuntimeWarning: divide by zero encountered in divide
#   v = b / KtransposeU
# C:\Users\micha\anaconda3\envs\gpu_compute_env\Lib\site-packages\ot\bregman.py:503: RuntimeWarning: overflow encountered in divide
#   v = b / KtransposeU
# C:\Users\micha\anaconda3\envs\gpu_compute_env\Lib\site-packages\ot\bregman.py:511: UserWarning: Warning: numerical errors at iteration 0
#   warnings.warn('Warning: numerical errors at iteration %d' % ii)

# %%
plt.imshow(M)

M.shape
# Out:
# (1250, 1963)

# %%
plt.figure(figsize=(16,8))

plt.subplot(1,2,1)
plt.imshow(Pi>0)
plt.title("Non-zero values of Wasserstein Optimal Transport Plan")

plt.subplot(1,2,2)
plt.imshow(Pi2>0)
plt.title("Non-zero values of Sinkhorn Optimal Transport Plan")

Pi.shape
# Out:
# (1250, 1963)

# %%
measure_list=[]

for subject in df['Cingulum_Frontal_Parahippocampal_R']:
    if type(subject)==DT_GMM:
        measure_list.append(subject)

# %%
barycenter=free_support_barycenter_update(measure_list)

plt.figure().add_subplot(projection='3d')
barycenter.plot()
plt.show()

for i in range(8):
    
    barycenter=free_support_barycenter_update(measure_list, barycenter)
    # barycenter=free_support_sinkhorn_barycenter_update(measure_list, barycenter)
    
    plt.figure().add_subplot(projection='3d')
    barycenter.plot()
    plt.show()

# %%
fig = plt.figure(figsize = (12,6))

ax = fig.add_subplot(121, projection='3d')
free_support_barycenter_update(measure_list).plot()
ax.set_title("Initial Barycenter")

ax = fig.add_subplot(122, projection='3d')
barycenter.plot()
ax.set_title("Barycenter after 10 iterations")

plt.show()
# plt.savefig("data_files/images/Barycenter_example.png",bbox_inches='tight')

# %%
barycenter

# %%
xs=torch.tensor(barycenter.means_.astype(float) )
xt=torch.tensor(measure_list[0].means_.astype(float))

u = torch.randn(200, requires_grad=True)
v = torch.randn(1623, requires_grad=True)


reg = 0.01

optimizer = torch.optim.Adam([u, v], lr=20)

# number of iteration
n_iter = 1000


losses = []


for i in range(n_iter):

    # generate noise samples

    # minus because we maximize te dual loss
    loss = -ot.stochastic.loss_dual_quadratic(u, v, xs,  xt, reg=reg)
    losses.append(float(loss.detach()))

    if i % 100 == 0:
        print("Iter: {:3d}, loss={}".format(i, losses[-1]))

    loss.backward()
    optimizer.step()
    optimizer.zero_grad()


plt.figure(4)
plt.plot(losses)
plt.grid()
plt.title('Dual objective (negative)')
plt.xlabel("Iterations")

Gq = ot.stochastic.plan_dual_quadratic(u, v, xs, xt, reg=reg)
# Out:
# Iter:   0, loss=-0.07430793204773145
# Iter: 100, loss=-60.33821069660856
# Iter: 200, loss=-99.52908786191838
# Iter: 300, loss=-110.70801034669972
# Iter: 400, loss=-117.98919517671533
# Iter: 500, loss=-122.92108530198001
# Iter: 600, loss=-125.86853057458411
# Iter: 700, loss=-127.91574951719292
# Iter: 800, loss=-128.70342659767556
# Iter: 900, loss=-128.5164011202233

# %%
u-torch.mean(u)
# Out:
# tensor([-377.2527, -119.6579,  113.5568,  289.8202, -328.3147,  132.7029,
#          251.4480,  288.1876, -107.4449,  317.6266, -356.8784,  307.5943,
#          314.6438,  177.2029,  316.8626, -423.8836, -305.0607,  298.0787,
#          -27.0157, -437.9415, -305.4201, -452.0493,  -86.7930,  265.6084,
#           20.7579,   85.6438,  199.4311,  318.8503,  237.0921, -377.6680,
#          281.9617,  251.7719,  318.1992,  313.9592,   -2.9537, -341.9053,
#          315.1488, -431.0593,  148.5916,   44.5707,  158.1046, -164.5917,
#          -73.5299,  241.5816,   33.4713, -474.4845,  246.9926, -177.9195,
#          283.9974,  101.0664, -246.1138,  282.7841,  -13.5762,  -43.2825,
#          293.8972, -126.7922,  -33.2877,  312.2442,  258.8970,  316.4095,
#          244.9696, -278.2025,  139.9177, -302.5197, -187.3505, -431.1589,
#           -9.6017,  214.6136,  314.5933, -162.0008,  276.8003,  180.4127,
#           75.2382, -204.4988,  132.9798, -151.5580, -258.2393,  259.1866,
#          281.5812,  319.5837, -279.5125,  267.8066,  -20.3386,  290.4727,
#          308.5284,  166.8559, -167.4437,  317.2860,  150.7666, -233.4781,
#         -249.2285,  121.2068, -484.9647,  213.6659,  298.3231, -320.8705,
#          302.6981, -274.5356,   67.4501, -446.8176, -397.4619,  -60.9607,
#         -372.2680,  313.0485,  311.4523, -108.3915,  207.1703, -198.1921,
#         -315.6179, -142.1351,  272.1529, -389.1199,  154.9888, -184.7834,
#         -433.3739, -478.3094,  226.9310,  -56.4951,  -93.6702, -394.9134,
#          274.6642,  -87.2638,   14.0737,  186.2633, -220.4339,  259.8597,
#          309.7333,  319.9265,  319.8956, -129.6543,  164.4253,   76.7423,
#         -393.1391,  244.9513,  319.1211,  300.2048,  120.2731, -419.9908,
#          305.2817, -328.3334, -108.2645, -238.8616,  259.6324,  318.3239,
#         -209.4421,  306.5904,  270.1192, -368.5758, -364.8692,  225.5017,
#         -427.0374,  200.9284,  204.0259,  195.7910, -302.4384,  248.6048,
#          -64.2026, -434.8002,   24.6050, -142.1757, -260.4556, -280.9589,
#         -504.8619,  -57.3397,   49.7728, -327.7736,   55.3495, -349.1865,
#         -267.2565,  193.2688,  299.0144,   62.6789,  315.2250,  306.6729,
#          277.7221,   98.5173,  229.0564,  265.6354, -351.8752,   88.3516,
#          241.6572,  223.3051,   19.3592,  318.9570, -345.8886, -197.3782,
#         -377.7629, -410.8878,  292.5941,  215.6283, -405.5884,    4.2243,
#         -397.7047, -360.9659, -221.0418, -212.5325,  294.5652, -288.8522,
#         -226.1806,  116.3316], grad_fn=<SubBackward0>)
