# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

from scipy.io import loadmat
from dtmrpy.io import loadsrc, loadfib, loadtdi, generate_tt

from dtmrpy import get_diffusion_data, get_diffusion_data_hcp, get_covariances, DT_GMM

# %%
main_folder = "C:\\Users\\micha\\OneDrive - Florida State University\\Projects\\DTMRI\\HCP\\"
data_folder = main_folder+"HCP_YA1065_QSDR_FIB\\"
save_folder = "C:\\Users\\micha\\Desktop\\New folder\\"

covariates = pd.read_csv(main_folder+"subject_info.csv")

sid = covariates['Subject'].values.astype(str)
tract_names = pd.read_csv("C:\\Users\\micha\\OneDrive - Florida State University\\Projects\\DTMRI\\roi_names.csv", header=None)[0].values.astype(str)
labels = covariates['Gender'].to_numpy()

# %%
# file_list = os.listdir('C:\\Users\\micha\\OneDrive - Florida State University\\Projects\\DTMRI\\HCP\\HCP_YA1065_QSDR_FIB')

# subject_folder = source_folder+str(num)

# for file in file_list:
#     sid_temp=file.split('.')[0]
#     subject_folder = source_folder+str(sid_temp)
#     os.makedirs(subject_folder)
    
    
#     source_file = 'C:\\Users\\micha\\OneDrive - Florida State University\\Projects\\DTMRI\\HCP\\HCP_YA1065_QSDR_FIB\\'+file
#     destination_file = subject_folder+'\\'+file
#     shutil.copy2(source_file, destination_file)

# %%
sid
# Out:
# array(['100004', '100206', '100307', ..., '994273', '995174', '996782'],
#       dtype='<U21')

# %%
tract_names
# Out:
# array([' Cingulum_Frontal_Parahippocampal_L',
#        'Cingulum_Frontal_Parahippocampal_R',
#        ' Cingulum_Frontal_Parietal_L', 'Cingulum_Frontal_Parietal_R',
#        '  Cingulum_Parahippocampal_L', ' Cingulum_Parahippocampal_R',
#        ' Cingulum_Parahippocampal_Parietal_L',
#        ' Cingulum_Parahippocampal_Parietal_R', ' Cingulum_Parolfactory_L',
#        ' Cingulum_Parolfactory_R', ' Corpus_Callosum_Body',
#        ' Corpus_Callosum_Forceps_Major', ' Corpus_Callosum_Forceps_Minor',
#        ' Corpus_Callosum_Tapetum', ' Fornix_L', ' Fornix_R',
#        ' Superior_Longitudinal_Fasciculus1_L',
#        ' Superior_Longitudinal_Fasciculus1_R',
#        ' Superior_Longitudinal_Fasciculus2_L',
#        '  Superior_Longitudinal_Fasciculus2_R',
#        ' Superior_Longitudinal_Fasciculus3_L',
#        ' Superior_Longitudinal_Fasciculus3_R', ' Uncinate_Fasciculus_L',
#        ' Uncinate_Fasciculus_R'], dtype='<U37')

# %%
subject_id = sid[1]
tract_name='Cingulum_Frontal_Parahippocampal_R'

src_filename=main_folder+subject_id+".src.gz"
fib_filename=data_folder+subject_id+".src.gz.icbm152_adult.qsdr.1.25.R70.fib.gz"
# tt_filename = data_folder+subject_id+'\\'+subject_id+'.'+tract_name+'.tt.gz'

src = loadsrc(src_filename)
fib = loadfib(fib_filename)

# tract = loadtdi(fib_filename, tt_filename)

# %%
src.keys()
# Out:
# dict_keys(['dimension', 'voxel_size', 'b_table', 'grad_dev', 'mask', 'image0', 'image1', 'image2', 'image3', 'image4', 'image5', 'image6', 'image7', 'image8', 'image9', 'image10', 'image11', 'image12', 'image13', 'image14', 'image15', 'image16', 'image17', 'image18', 'image19', 'image20', 'image21', 'image22', 'image23', 'image24', 'image25', 'image26', 'image27', 'image28', 'image29', 'image30', 'image31', 'image32', 'image33', 'image34', 'image35', 'image36', 'image37', 'image38', 'image39', 'image40', 'image41', 'image42', 'image43', 'image44', 'image45', 'image46', 'image47', 'image48', 'image49', 'image50', 'image51', 'image52', 'image53', 'image54', 'image55', 'image56', 'image57', 'image58', 'image59', 'image60', 'image61', 'image62', 'image63', 'image64', 'image65', 'image66', 'image67', 'image68', 'image69', 'image70', 'image71', 'image72', 'image73', 'image74', 'image75', 'image76', 'image77', 'image78', 'image79', 'image80', 'image81', 'image82', 'image83', 'image84', 'image85', 'image86', 'image87', 'image88', 'image89', 'image90', 'image91', 'image92', 'image93', 'image94', 'image95', 'image96', 'image97', 'image98', 'image99', 'image100', 'image101', 'image102', 'image103', 'image104', 'image105', 'image106', 'image107', 'image108', 'image109', 'image110', 'image111', 'image112', 'image113', 'image114', 'image115', 'image116', 'image117', 'image118', 'image119', 'image120', 'image121', 'image122', 'image123', 'image124', 'image125', 'image126', 'image127', 'image128', 'image129', 'image130', 'image131', 'image132', 'image133', 'image134', 'image135', 'image136', 'image137', 'image138', 'image139', 'image140', 'image141', 'image142', 'image143', 'image144', 'image145', 'image146', 'image147', 'image148', 'image149', 'image150', 'image151', 'image152', 'image153', 'image154', 'image155', 'image156', 'image157', 'image158', 'image159', 'image160', 'image161', 'image162', 'image163', 'image164', 'image165', 'image166', 'image167', 'image168', 'image169', 'image170', 'image171', 'image172', 'image173', 'image174', 'image175', 'image176', 'image177', 'image178', 'image179', 'image180', 'image181', 'image182', 'image183', 'image184', 'image185', 'image186', 'image187', 'image188', 'image189', 'image190', 'image191', 'image192', 'image193', 'image194', 'image195', 'image196', 'image197', 'image198', 'image199', 'image200', 'image201', 'image202', 'image203', 'image204', 'image205', 'image206', 'image207', 'image208', 'image209', 'image210', 'image211', 'image212', 'image213', 'image214', 'image215', 'image216', 'image217', 'image218', 'image219', 'image220', 'image221', 'image222', 'image223', 'image224', 'image225', 'image226', 'image227', 'image228', 'image229', 'image230', 'image231', 'image232', 'image233', 'image234', 'image235', 'image236', 'image237', 'image238', 'image239', 'image240', 'image241', 'image242', 'image243', 'image244', 'image245', 'image246', 'image247', 'image248', 'image249', 'image250', 'image251', 'image252', 'image253', 'image254', 'image255', 'image256', 'image257', 'image258', 'image259', 'image260', 'image261', 'image262', 'image263', 'image264', 'image265', 'image266', 'image267', 'image268', 'image269', 'image270', 'report'])

# %%
fib.keys()
# Out:
# dict_keys(['dimension', 'voxel_size', 'odf_vertices', 'odf_faces', 'native_dimension', 'native_voxel_size', 'mapping', 'trans', 'R2', 'dti_fa', 'md', 'ad', 'rd', 'fa0', 'fa1', 'fa2', 'fa3', 'fa4', 'iso', 'rdi', 'nrdi02L', 'nrdi04L', 'nrdi06L', 'index0', 'index1', 'index2', 'index3', 'index4', 'report', 'steps'])

# %%
src['dimension']
# Out:
# array([[145, 174, 145]], dtype=int16)

# %%
fib['dimension']
# Out:
# array([[125, 151, 108]])

# %%
data=get_covariances(fib, num_dir=5)
data.shape
# Out:
# (151, 125, 108, 3, 3)

# %%
data_new = np.zeros((151,125,108,3))

for i in range(151):
    for j in range(125):
        for k in range(108):
            temp=np.diag(data[i,j,k])
            if sum(abs(temp))>0:
                data_new[i,j,k,:] = abs(temp)/sum(abs(temp))

# %%
m=54

plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.imshow(src['image30'].reshape(src['dimension'][0])[m,:,:])
plt.subplot(1,2,2)
# plt.imshow(abs(data_new[:,:,54,:])/abs(np.max(data_new[:,:,54,:])))
plt.imshow(data_new[:,:,m,:])

plt.show()

# plt.savefig("data_files/images/updated_src_fib.png")

# %%
df = pd.DataFrame(columns=["sid"]+["label"]+[tract.strip() for tract in tract_names])
df['sid']=sid
df['label']=labels
df
# Out:
#          sid label Cingulum_Frontal_Parahippocampal_L  \
# 0     100004     M                                NaN
# 1     100206     M                                NaN
# 2     100307     F                                NaN
# 3     100408     M                                NaN
# 4     100610     M                                NaN
# ...      ...   ...                                ...
# 1201  992774     M                                NaN
# 1202  993675     F                                NaN
# 1203  994273     M                                NaN
# 1204  995174     M                                NaN
# 1205  996782     F                                NaN
#
#      Cingulum_Frontal_Parahippocampal_R Cingulum_Frontal_Parietal_L  \
# 0                                   NaN                         NaN
# 1                                   NaN                         NaN
# 2                                   NaN                         NaN
# 3                                   NaN                         NaN
# 4                                   NaN                         NaN
# ...                                 ...                         ...
# 1201                                NaN                         NaN
# 1202                                NaN                         NaN
# 1203                                NaN                         NaN
# 1204                                NaN                         NaN
# 1205                                NaN                         NaN
#
#      Cingulum_Frontal_Parietal_R Cingulum_Parahippocampal_L  \
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                            NaN                        NaN
# ...                          ...                        ...
# 1201                         NaN                        NaN
# 1202                         NaN                        NaN
# 1203                         NaN                        NaN
# 1204                         NaN                        NaN
# 1205                         NaN                        NaN
#
#      Cingulum_Parahippocampal_R Cingulum_Parahippocampal_Parietal_L  \
# 0                           NaN                                 NaN
# 1                           NaN                                 NaN
# 2                           NaN                                 NaN
# 3                           NaN                                 NaN
# 4                           NaN                                 NaN
# ...                         ...                                 ...
# 1201                        NaN                                 NaN
# 1202                        NaN                                 NaN
# 1203                        NaN                                 NaN
# 1204                        NaN                                 NaN
# 1205                        NaN                                 NaN
#
#      Cingulum_Parahippocampal_Parietal_R  ... Fornix_L Fornix_R  \
# 0                                    NaN  ...      NaN      NaN
# 1                                    NaN  ...      NaN      NaN
# 2                                    NaN  ...      NaN      NaN
# 3                                    NaN  ...      NaN      NaN
# 4                                    NaN  ...      NaN      NaN
# ...                                  ...  ...      ...      ...
# 1201                                 NaN  ...      NaN      NaN
# 1202                                 NaN  ...      NaN      NaN
# 1203                                 NaN  ...      NaN      NaN
# 1204                                 NaN  ...      NaN      NaN
# 1205                                 NaN  ...      NaN      NaN
#
#      Superior_Longitudinal_Fasciculus1_L Superior_Longitudinal_Fasciculus1_R  \
# 0                                    NaN                                 NaN
# 1                                    NaN                                 NaN
# 2                                    NaN                                 NaN
# 3                                    NaN                                 NaN
# 4                                    NaN                                 NaN
# ...                                  ...                                 ...
# 1201                                 NaN                                 NaN
# 1202                                 NaN                                 NaN
# 1203                                 NaN                                 NaN
# 1204                                 NaN                                 NaN
# 1205                                 NaN                                 NaN
#
#      Superior_Longitudinal_Fasciculus2_L Superior_Longitudinal_Fasciculus2_R  \
# 0                                    NaN                                 NaN
# 1                                    NaN                                 NaN
# 2                                    NaN                                 NaN
# 3                                    NaN                                 NaN
# 4                                    NaN                                 NaN
# ...                                  ...                                 ...
# 1201                                 NaN                                 NaN
# 1202                                 NaN                                 NaN
# 1203                                 NaN                                 NaN
# 1204                                 NaN                                 NaN
# 1205                                 NaN                                 NaN
#
#      Superior_Longitudinal_Fasciculus3_L Superior_Longitudinal_Fasciculus3_R  \
# 0                                    NaN                                 NaN
# 1                                    NaN                                 NaN
# 2                                    NaN                                 NaN
# 3                                    NaN                                 NaN
# 4                                    NaN                                 NaN
# ...                                  ...                                 ...
# 1201                                 NaN                                 NaN
# 1202                                 NaN                                 NaN
# 1203                                 NaN                                 NaN
# 1204                                 NaN                                 NaN
# 1205                                 NaN                                 NaN
#
#      Uncinate_Fasciculus_L Uncinate_Fasciculus_R
# 0                      NaN                   NaN
# 1                      NaN                   NaN
# 2                      NaN                   NaN
# 3                      NaN                   NaN
# 4                      NaN                   NaN
# ...                    ...                   ...
# 1201                   NaN                   NaN
# 1202                   NaN                   NaN
# 1203                   NaN                   NaN
# 1204                   NaN                   NaN
# 1205                   NaN                   NaN
#
# [1206 rows x 26 columns]

# %%
num_dir=5

subject_list = os.listdir('C:\\Users\\micha\\OneDrive - Florida State University\\Projects\\DTMRI\\HCP\\HCP_data')

# for subject_id in df['sid']:
for subject_id in subject_list:
    print(subject_id)
    
    subject_folder = 'C:\\Users\\micha\\OneDrive - Florida State University\\Projects\\DTMRI\\HCP\\HCP_data\\'+subject_id.strip()+'\\'

    #Get fib filenames
    file_list = os.listdir('C:\\Users\\micha\\OneDrive - Florida State University\\Projects\\DTMRI\\HCP\\HCP_data\\'+subject_id.strip()+'\\')
    #This is a bad way to check; the issues is the R70 in the file names
    for file in file_list:
        if file[-3:]=='.gz':
            fib_filename=subject_folder+file
  
    if os.path.exists(fib_filename):
        
        #Load fib file for subject
        fib = loadfib(fib_filename)
        
        #Check that images are expected shape
        fib_dim = fib['dimension'][0]

        if (fib_dim==[125, 151, 108]).all():
            
            #fib file contains multiple directions and magnitiudes for each voxel in full image
            #'diffusion tensors' are actually covariance matrices
            covariances_full = get_covariances(fib)

            for tract in tract_names:

                #Load .tt file for tract for subject, skip if file not found 
                # tt_filename = subject_folder + subject_id.strip()+'.'+tract.strip()+'.tt.gz'
                tt_filename = subject_folder +tract.strip()+'\\'+subject_id.strip()+'.'+tract.strip()+'.tt.gz'
                
                
                if os.path.exists(tt_filename):
                    
                    #Get tdi file from dsi studio - this provides estimated fiber counts for voxels in tract
                    #implicitly provides a segmentation for tract, in coordinates of full MRI image (in particular, consistent with fib file)
                    tract_data = loadtdi(fib_filename, tt_filename)
                    tract_coord = np.transpose(tract_data,[1,0,2])

                    #Means for a region are taken as voxels with non-zero number of fibers, as estimated by dsi studio
                    means = np.array(np.nonzero(tract_coord)).T 
                    #weights are the non-zero values in the tdi file 
                    weights = tract_coord[means[:,0],means[:,1],means[:,2]].reshape(-1,1)                    
                    #get covariances for voxels in tract
                    covariances = covariances_full[means[:,0],means[:,1],means[:,2],:,:]

                    #insert DT_GMM object into pandas dataframe
                    df.at[df.index[df['sid']==subject_id][0],tract.strip()] = DT_GMM(weights,means,covariances)

                else:
                    os.mkdir(subject_folder +tract.strip()+'\\')
                    #create tdi file 
                    generate_tt(fib_filename, tract.strip(), tt_filename)
                    
                    if os.path.exists(tt_filename):
                        #Get tdi file from dsi studio - this provides estimated fiber counts for voxels in tract
                        #implicitly provides a segmentation for tract, in coordinates of full MRI image (in particular, consistent with fib file)
                        tract_data = loadtdi(fib_filename, tt_filename)
                        tract_coord = np.transpose(tract_data,[1,0,2])

                        #Means for a region are taken as voxels with non-zero number of fibers, as estimated by dsi studio
                        means = np.array(np.nonzero(tract_coord)).T 
                        #weights are the non-zero values in the tdi file 
                        weights = tract_coord[means[:,0],means[:,1],means[:,2]].reshape(-1,1)                    
                        #get covariances for voxels in tract
                        covariances = covariances_full[means[:,0],means[:,1],means[:,2],:,:]

                        #insert DT_GMM object into pandas dataframe
                        df.at[df.index[df['sid']==subject_id][0],tract.strip()] = DT_GMM(weights,means,covariances)
                    else:
                        print(tract.strip() + " .tt file not found")

        else:
            print(subject_id+" not correct dimension")
            
    else:
        print(subject_id + ' ' + "fib not found")     
    
    print(" ")
    
df.to_pickle("data_files/dtmri_dataframe_11_2.pkl")
# Out:
# 100206
# Corpus_Callosum_Tapetum .tt file not found
# Fornix_L .tt file not found
#
# 100307
#
# 100408
#
# 100610
#
# 101006
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 101107
#
# 101309
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 101410
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 101915
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
# Corpus_Callosum_Forceps_Major .tt file not found
#
# 102008
#
# 102109
#
# 102311
#
# 102513
#
# 102614
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 102715
#
# 102816
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 103010
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
# Fornix_L .tt file not found
#
# 103111
# Cingulum_Frontal_Parahippocampal_R .tt file not found
# Cingulum_Parahippocampal_Parietal_L .tt file not found
#
# 103212
#
# 103414
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 103515
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 103818
#
# 104012
#
# 104416
#
# 104820
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 105014
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 105115
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 105216
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 105620
# Corpus_Callosum_Tapetum .tt file not found
#
# 105923
#
# 106016
#
# 106319
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 106521
#
# 106824
#
# 107018
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 107321
#
# 107422
#
# 107725
#
# 108020
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 108121
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 108222
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 108323
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 108525
#
# 108828
#
# 109123
#
# 109830
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 110007
# Cingulum_Frontal_Parahippocampal_L .tt file not found
#
# 110411
#
# 110613
# Corpus_Callosum_Tapetum .tt file not found
#
# 111009
# Cingulum_Frontal_Parahippocampal_R .tt file not found
# Corpus_Callosum_Tapetum .tt file not found
#
# 111211
# Cingulum_Frontal_Parahippocampal_L .tt file not found
#
# 111312
#
# 111413
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 111514
#
# 111716
# Cingulum_Frontal_Parahippocampal_L .tt file not found
#
# 112112
#
# 112314
#
# 112516
#
# 112819
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 112920
#
# 113215
#
# 113316
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
# Corpus_Callosum_Tapetum .tt file not found
#
# 113619
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 113821
#
# 113922
# Cingulum_Frontal_Parahippocampal_L .tt file not found
#
# 114116
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 114217
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 114318
#
# 114419
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 114621
#
# 114823
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 115017
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 115219
# Corpus_Callosum_Tapetum .tt file not found
#
# 115320
#
# 115724
#
# 115825
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 116221
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 116423
#
# 116524
#
# 116726
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 117021
#
# 117122
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 117324
#
# 117930
#
# 118023
# Fornix_L .tt file not found
#
# 118124
#
# 118225
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 118528
#
# 118730
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
# Cingulum_Parahippocampal_Parietal_R .tt file not found
#
# 118831
#
# 118932
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 119025
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 119126
#
# 119732
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
# Cingulum_Parahippocampal_Parietal_R .tt file not found
#
# 119833
# Corpus_Callosum_Tapetum .tt file not found
#
# 120010
#
# 120111
#
# 120212
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 120414
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 120515
#
# 120717
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 121416
# Corpus_Callosum_Tapetum .tt file not found
#
# 121618
#
# 121719
# Cingulum_Frontal_Parahippocampal_L .tt file not found
#
# 121921
#
# 122317
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 122418
#
# 122620
#
# 122822
#
# 123117
# Cingulum_Frontal_Parahippocampal_L .tt file not found
#
# 123420
# Corpus_Callosum_Tapetum .tt file not found
# Fornix_L .tt file not found
#
# 123521
#
# 123723
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 123824
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 123925
#
# 124220
#
# 124422
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 124624
#
# 124826
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 125222
#
# 125424
# Corpus_Callosum_Tapetum .tt file not found
#
# 125525
# Cingulum_Frontal_Parahippocampal_L .tt file not found
#
# 126325
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 126426
#
# 126628
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 127226
#
# 127327
#
# 127630
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 127731
# Cingulum_Frontal_Parahippocampal_L .tt file not found
#
# 127832
# Cingulum_Frontal_Parahippocampal_L .tt file not found
#
# 127933
#
# 128026
# Cingulum_Frontal_Parahippocampal_L .tt file not found
#
# 128127
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 128632
#
# 128935
#
# 129028
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 129129
#
# 129331
#
# 129634
#
# 129937
#
# 130013
# Corpus_Callosum_Tapetum .tt file not found
#
# 130114
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 130316
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 130417
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 130518
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 130619
# Corpus_Callosum_Tapetum .tt file not found
#
# 130720
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 130821
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 130922
#
# 131217
# Cingulum_Frontal_Parahippocampal_L .tt file not found
#
# 131419
#
# 131722
#
# 131823
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 131924
#
# 132017
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 132118
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 133019
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 133625
# Cingulum_Frontal_Parahippocampal_L .tt file not found
#
# 133827
#
# 133928
#
# 134021
#
# 134223
#
# 134324
#
# 134425
#
# 134627
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
# Corpus_Callosum_Tapetum .tt file not found
#
# 134728
# Fornix_R .tt file not found
#
# 134829
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 135124
# Cingulum_Frontal_Parahippocampal_L .tt file not found
#
# 135225
#
# 135528
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 135629
#
# 135730
#
# 135932
#
# 136126
#
# 136227
#
# 136631
#
# 136732
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 136833
#
# 137027
#
# 137128
# Cingulum_Frontal_Parahippocampal_L .tt file not found
#
# 137229
#
# 137431
#
# 137532
#
# 137633
#
# 137936
#
# 138130
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 138231
#
# 138332
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
# Fornix_R .tt file not found
#
# 138534
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 138837
#
# 139233
#
# 139435
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 139637
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 139839
#
# 140117
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 140319
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 140420
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 140824
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 140925
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 141119
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 141422
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 141826
#
# 142828
#
# 143224
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
# Fornix_R .tt file not found
#
# 143325
#
# 143426
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 143830
#
# 144125
# Corpus_Callosum_Tapetum .tt file not found
#
# 144226
#
# 144428
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 144731
#
# 144832
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 144933
#
# 145127
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 145632
#
# 145834
#
# 146129
#
# 146331
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 146432
# Corpus_Callosum_Tapetum .tt file not found
#
# 146533
# Corpus_Callosum_Tapetum .tt file not found
#
# 146634
#
# 146735
# Corpus_Callosum_Tapetum .tt file not found
#
# 146836
# Corpus_Callosum_Tapetum .tt file not found
#
# 146937
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 147030
#
# 147636
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 147737
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 148032
#
# 148133
# Corpus_Callosum_Tapetum .tt file not found
#
# 148335
#
# 148436
#
# 148840
#
# 148941
#
# 149236
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
# Cingulum_Frontal_Parietal_R .tt file not found
# Cingulum_Parahippocampal_Parietal_L .tt file not found
#
# 149337
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 149539
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Parahippocampal_Parietal_L .tt file not found
#
# 149741
#
# 149842
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 150019
#
# 150524
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 150625
#
# 150726
#
# 150928
#
# 151021
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 151223
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 151324
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 151425
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 151526
#
# 151627
#
# 151728
#
# 151829
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 151930
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 152225
# Cingulum_Parahippocampal_Parietal_L .tt file not found
#
# 152427
#
# 152831
#
# 153025
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 153126
#
# 153227
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 153429
#
# 153631
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 153732
#
# 153833
#
# 153934
#
# 154229
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 154330
#
# 154431
#
# 154532
#
# 154734
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Corpus_Callosum_Tapetum .tt file not found
#
# 154835
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 154936
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 155231
#
# 155635
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 155938
#
# 156031
#
# 156233
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 156334
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 156435
#
# 156536
# Corpus_Callosum_Tapetum .tt file not found
#
# 156637
# Cingulum_Frontal_Parahippocampal_L .tt file not found
#
# 157336
#
# 157437
#
# 157942
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
# Fornix_R .tt file not found
#
# 158035
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 158136
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 158338
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 158540
#
# 158843
#
# 159138
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 159239
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 159340
#
# 159441
#
# 159744
# Cingulum_Frontal_Parahippocampal_L .tt file not found
#
# 159946
#
# 160123
#
# 160729
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
# Cingulum_Parahippocampal_Parietal_R .tt file not found
#
# 160830
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
# Corpus_Callosum_Tapetum .tt file not found
#
# 160931
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 161327
#
# 161630
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 161731
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 161832
#
# 162026
#
# 162228
# Corpus_Callosum_Tapetum .tt file not found
#
# 162329
#
# 162733
#
# 162935
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 163129
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 163331
#
# 163432
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 163836
#
# 164030
#
# 164131
#
# 164636
#
# 164939
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 165032
#
# 165436
#
# 165638
# Corpus_Callosum_Tapetum .tt file not found
#
# 165840
#
# 165941
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 166438
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 166640
#
# 167036
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Corpus_Callosum_Tapetum .tt file not found
#
# 167238
#
# 167440
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 167743
#
# 168139
#
# 168240
#
# 168341
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
# Cingulum_Parahippocampal_Parietal_L .tt file not found
#
# 168745
# Cingulum_Parahippocampal_Parietal_L .tt file not found
# Corpus_Callosum_Tapetum .tt file not found
# Fornix_R .tt file not found
#
# 168947
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 169040
#
# 169343
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 169444
#
# 169545
#
# 169747
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
# Cingulum_Parahippocampal_Parietal_R .tt file not found
#
# 169949
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
# Corpus_Callosum_Tapetum .tt file not found
#
# 170631
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 170934
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 171330
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 171431
#
# 171532
#
# 171633
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 172029
#
# 172130
#
# 172332
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
# Cingulum_Parahippocampal_Parietal_R .tt file not found
#
# 172433
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 172534
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 172635
#
# 172938
#
# 173132
#
# 173233
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found
#
# 173334
#
# 173435
#
# 173536
#
# 173637
# Cingulum_Frontal_Parahippocampal_L .tt file not found
# Cingulum_Frontal_Parahippocampal_R .tt file not found

# %%
df = pd.read_pickle("data_files/dtmri_dataframe_HCP.pkl")
df = df.dropna(subset=df.columns[2:],how='all').copy()
df.reset_index(inplace=True, drop=True)
df
# Out:
#         sid label                 Cingulum_Frontal_Parahippocampal_L  \
# 0    100206     M  <dtmrpy.dtmrpy.DT_GMM object at 0x000001671B83...
# 1    100307     F  <dtmrpy.dtmrpy.DT_GMM object at 0x000001671B83...
# 2    100408     M  <dtmrpy.dtmrpy.DT_GMM object at 0x000001671B83...
# 3    100610     M  <dtmrpy.dtmrpy.DT_GMM object at 0x000001671B83...
# 4    101006     F                                                NaN
# ..      ...   ...                                                ...
# 350  173233     M                                                NaN
# 351  173334     M  <dtmrpy.dtmrpy.DT_GMM object at 0x00000165D47B...
# 352  173435     F  <dtmrpy.dtmrpy.DT_GMM object at 0x00000165D47B...
# 353  173536     F  <dtmrpy.dtmrpy.DT_GMM object at 0x00000165D49F...
# 354  173637     F                                                NaN
#
#                     Cingulum_Frontal_Parahippocampal_R  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x00000165D49F...
# 1    <dtmrpy.dtmrpy.DT_GMM object at 0x00000165D49F...
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x00000165D49F...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x00000165D49F...
# 4                                                  NaN
# ..                                                 ...
# 350                                                NaN
# 351  <dtmrpy.dtmrpy.DT_GMM object at 0x00000166FF8F...
# 352  <dtmrpy.dtmrpy.DT_GMM object at 0x00000166FF8F...
# 353  <dtmrpy.dtmrpy.DT_GMM object at 0x00000166FF8F...
# 354                                                NaN
#
#                            Cingulum_Frontal_Parietal_L  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x00000166FF8F...
# 1    <dtmrpy.dtmrpy.DT_GMM object at 0x00000166FF8F...
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x00000166FF8F...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x00000166FF8F...
# 4    <dtmrpy.dtmrpy.DT_GMM object at 0x00000166FF8F...
# ..                                                 ...
# 350  <dtmrpy.dtmrpy.DT_GMM object at 0x00000165D355...
# 351  <dtmrpy.dtmrpy.DT_GMM object at 0x00000165D355...
# 352  <dtmrpy.dtmrpy.DT_GMM object at 0x00000165D355...
# 353  <dtmrpy.dtmrpy.DT_GMM object at 0x00000165D355...
# 354  <dtmrpy.dtmrpy.DT_GMM object at 0x00000165D355...
#
#                            Cingulum_Frontal_Parietal_R  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x00000165D355...
# 1    <dtmrpy.dtmrpy.DT_GMM object at 0x00000165D355...
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x00000165D355...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x00000165D355...
# 4    <dtmrpy.dtmrpy.DT_GMM object at 0x00000165D355...
# ..                                                 ...
# 350  <dtmrpy.dtmrpy.DT_GMM object at 0x00000165D4CA...
# 351  <dtmrpy.dtmrpy.DT_GMM object at 0x00000165D4CA...
# 352  <dtmrpy.dtmrpy.DT_GMM object at 0x00000165D4CA...
# 353  <dtmrpy.dtmrpy.DT_GMM object at 0x00000165D43D...
# 354  <dtmrpy.dtmrpy.DT_GMM object at 0x00000165D43D...
#
#                             Cingulum_Parahippocampal_L  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x00000165D43D...
# 1    <dtmrpy.dtmrpy.DT_GMM object at 0x00000165D43D...
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x00000165D43D...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x00000165D43D...
# 4    <dtmrpy.dtmrpy.DT_GMM object at 0x00000165D43D...
# ..                                                 ...
# 350  <dtmrpy.dtmrpy.DT_GMM object at 0x00000163CBE6...
# 351  <dtmrpy.dtmrpy.DT_GMM object at 0x00000163CBE6...
# 352  <dtmrpy.dtmrpy.DT_GMM object at 0x00000163CBE6...
# 353  <dtmrpy.dtmrpy.DT_GMM object at 0x00000163CBE6...
# 354  <dtmrpy.dtmrpy.DT_GMM object at 0x00000163CBE6...
#
#                             Cingulum_Parahippocampal_R  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x00000163CBE6...
# 1    <dtmrpy.dtmrpy.DT_GMM object at 0x00000163CBE6...
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x00000163CBE6...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x00000163CBE6...
# 4    <dtmrpy.dtmrpy.DT_GMM object at 0x00000163CBE6...
# ..                                                 ...
# 350  <dtmrpy.dtmrpy.DT_GMM object at 0x00000166E26F...
# 351  <dtmrpy.dtmrpy.DT_GMM object at 0x00000166E26F...
# 352  <dtmrpy.dtmrpy.DT_GMM object at 0x00000166E26F...
# 353  <dtmrpy.dtmrpy.DT_GMM object at 0x00000166E26F...
# 354  <dtmrpy.dtmrpy.DT_GMM object at 0x00000166E26F...
#
#                    Cingulum_Parahippocampal_Parietal_L  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x00000166E26F...
# 1    <dtmrpy.dtmrpy.DT_GMM object at 0x00000166E26F...
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x00000165D601...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x00000165D601...
# 4    <dtmrpy.dtmrpy.DT_GMM object at 0x00000165D601...
# ..                                                 ...
# 350  <dtmrpy.dtmrpy.DT_GMM object at 0x000001671E7D...
# 351  <dtmrpy.dtmrpy.DT_GMM object at 0x000001671E7D...
# 352  <dtmrpy.dtmrpy.DT_GMM object at 0x000001671E7D...
# 353  <dtmrpy.dtmrpy.DT_GMM object at 0x000001671E7D...
# 354  <dtmrpy.dtmrpy.DT_GMM object at 0x000001671E7D...
#
#                    Cingulum_Parahippocampal_Parietal_R  ...  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x000001671E7D...  ...
# 1    <dtmrpy.dtmrpy.DT_GMM object at 0x000001671E7D...  ...
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x000001671E7D...  ...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x000001671E7D...  ...
# 4    <dtmrpy.dtmrpy.DT_GMM object at 0x000001671E7D...  ...
# ..                                                 ...  ...
# 350  <dtmrpy.dtmrpy.DT_GMM object at 0x000001669159...  ...
# 351  <dtmrpy.dtmrpy.DT_GMM object at 0x000001669159...  ...
# 352  <dtmrpy.dtmrpy.DT_GMM object at 0x000001669159...  ...
# 353  <dtmrpy.dtmrpy.DT_GMM object at 0x000001669159...  ...
# 354  <dtmrpy.dtmrpy.DT_GMM object at 0x000001669159...  ...
#
#                                               Fornix_L  \
# 0                                                  NaN
# 1    <dtmrpy.dtmrpy.DT_GMM object at 0x00000167D8C0...
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x00000167D8C0...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x00000167D8C0...
# 4    <dtmrpy.dtmrpy.DT_GMM object at 0x00000167D8C0...
# ..                                                 ...
# 350  <dtmrpy.dtmrpy.DT_GMM object at 0x00000167DBD6...
# 351  <dtmrpy.dtmrpy.DT_GMM object at 0x00000167DBD6...
# 352  <dtmrpy.dtmrpy.DT_GMM object at 0x00000167DBD6...
# 353  <dtmrpy.dtmrpy.DT_GMM object at 0x00000167DBD6...
# 354  <dtmrpy.dtmrpy.DT_GMM object at 0x00000167DBD6...
#
#                                               Fornix_R  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x00000167DCD5...
# 1    <dtmrpy.dtmrpy.DT_GMM object at 0x00000167DCD5...
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x00000167DCD5...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x00000167DCD5...
# 4    <dtmrpy.dtmrpy.DT_GMM object at 0x00000167DCD5...
# ..                                                 ...
# 350  <dtmrpy.dtmrpy.DT_GMM object at 0x00000167DFDA...
# 351  <dtmrpy.dtmrpy.DT_GMM object at 0x00000167DFDA...
# 352  <dtmrpy.dtmrpy.DT_GMM object at 0x00000167DFDA...
# 353  <dtmrpy.dtmrpy.DT_GMM object at 0x00000167DFDA...
# 354  <dtmrpy.dtmrpy.DT_GMM object at 0x00000167DFDA...
#
#                    Superior_Longitudinal_Fasciculus1_L  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x00000167DFDA...
# 1    <dtmrpy.dtmrpy.DT_GMM object at 0x00000167DFDA...
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x00000167DFDA...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x00000167DFDA...
# 4    <dtmrpy.dtmrpy.DT_GMM object at 0x00000167DFDA...
# ..                                                 ...
# 350  <dtmrpy.dtmrpy.DT_GMM object at 0x00000167E9DC...
# 351  <dtmrpy.dtmrpy.DT_GMM object at 0x00000167E9DC...
# 352  <dtmrpy.dtmrpy.DT_GMM object at 0x00000167E9DC...
# 353  <dtmrpy.dtmrpy.DT_GMM object at 0x00000167E9DC...
# 354  <dtmrpy.dtmrpy.DT_GMM object at 0x00000167E9DC...
#
#                    Superior_Longitudinal_Fasciculus1_R  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x00000167E9DC...
# 1    <dtmrpy.dtmrpy.DT_GMM object at 0x00000167E9DC...
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x00000167E9DC...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x00000167E9DC...
# 4    <dtmrpy.dtmrpy.DT_GMM object at 0x00000167E9DC...
# ..                                                 ...
# 350  <dtmrpy.dtmrpy.DT_GMM object at 0x00000167F6C5...
# 351  <dtmrpy.dtmrpy.DT_GMM object at 0x00000167F6C5...
# 352  <dtmrpy.dtmrpy.DT_GMM object at 0x00000167F6C5...
# 353  <dtmrpy.dtmrpy.DT_GMM object at 0x00000167F6C5...
# 354  <dtmrpy.dtmrpy.DT_GMM object at 0x00000167F6C5...
#
#                    Superior_Longitudinal_Fasciculus2_L  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x00000167F6C5...
# 1    <dtmrpy.dtmrpy.DT_GMM object at 0x00000167F6C5...
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x00000167F6C5...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x00000167F6C5...
# 4    <dtmrpy.dtmrpy.DT_GMM object at 0x00000167F6C5...
# ..                                                 ...
# 350  <dtmrpy.dtmrpy.DT_GMM object at 0x000001680F5B...
# 351  <dtmrpy.dtmrpy.DT_GMM object at 0x000001680F5B...
# 352  <dtmrpy.dtmrpy.DT_GMM object at 0x000001680F5B...
# 353  <dtmrpy.dtmrpy.DT_GMM object at 0x000001680F5B...
# 354  <dtmrpy.dtmrpy.DT_GMM object at 0x000001680F5B...
#
#                    Superior_Longitudinal_Fasciculus2_R  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x000001680F5B...
# 1    <dtmrpy.dtmrpy.DT_GMM object at 0x000001680F5B...
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x000001680F5B...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x000001680F5B...
# 4    <dtmrpy.dtmrpy.DT_GMM object at 0x000001680F5B...
# ..                                                 ...
# 350  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016830F9...
# 351  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016830F9...
# 352  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016830F9...
# 353  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016830F9...
# 354  <dtmrpy.dtmrpy.DT_GMM object at 0x0000016830F9...
#
#                    Superior_Longitudinal_Fasciculus3_L  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x0000016830F9...
# 1    <dtmrpy.dtmrpy.DT_GMM object at 0x0000016830F9...
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x0000016830F9...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x0000016830F9...
# 4    <dtmrpy.dtmrpy.DT_GMM object at 0x0000016830F9...
# ..                                                 ...
# 350  <dtmrpy.dtmrpy.DT_GMM object at 0x000001683E35...
# 351  <dtmrpy.dtmrpy.DT_GMM object at 0x000001683E35...
# 352  <dtmrpy.dtmrpy.DT_GMM object at 0x000001683E35...
# 353  <dtmrpy.dtmrpy.DT_GMM object at 0x000001683E35...
# 354  <dtmrpy.dtmrpy.DT_GMM object at 0x000001683E35...
#
#                    Superior_Longitudinal_Fasciculus3_R  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x000001683E35...
# 1    <dtmrpy.dtmrpy.DT_GMM object at 0x000001683E35...
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x000001683E35...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x000001683E35...
# 4    <dtmrpy.dtmrpy.DT_GMM object at 0x000001683E35...
# ..                                                 ...
# 350  <dtmrpy.dtmrpy.DT_GMM object at 0x000001685043...
# 351  <dtmrpy.dtmrpy.DT_GMM object at 0x000001685043...
# 352  <dtmrpy.dtmrpy.DT_GMM object at 0x000001685043...
# 353  <dtmrpy.dtmrpy.DT_GMM object at 0x000001685045...
# 354  <dtmrpy.dtmrpy.DT_GMM object at 0x000001685045...
#
#                                  Uncinate_Fasciculus_L  \
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x000001685045...
# 1    <dtmrpy.dtmrpy.DT_GMM object at 0x000001685045...
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x000001685045...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x000001685045...
# 4    <dtmrpy.dtmrpy.DT_GMM object at 0x000001685045...
# ..                                                 ...
# 350  <dtmrpy.dtmrpy.DT_GMM object at 0x000001685C40...
# 351  <dtmrpy.dtmrpy.DT_GMM object at 0x000001685C40...
# 352  <dtmrpy.dtmrpy.DT_GMM object at 0x000001685C40...
# 353  <dtmrpy.dtmrpy.DT_GMM object at 0x000001685C40...
# 354  <dtmrpy.dtmrpy.DT_GMM object at 0x000001685C40...
#
#                                  Uncinate_Fasciculus_R
# 0    <dtmrpy.dtmrpy.DT_GMM object at 0x000001685C40...
# 1    <dtmrpy.dtmrpy.DT_GMM object at 0x000001685C40...
# 2    <dtmrpy.dtmrpy.DT_GMM object at 0x000001685C40...
# 3    <dtmrpy.dtmrpy.DT_GMM object at 0x000001685C40...
# 4    <dtmrpy.dtmrpy.DT_GMM object at 0x000001685C40...
# ..                                                 ...
# 350  <dtmrpy.dtmrpy.DT_GMM object at 0x000001686437...
# 351  <dtmrpy.dtmrpy.DT_GMM object at 0x000001686437...
# 352  <dtmrpy.dtmrpy.DT_GMM object at 0x000001686437...
# 353  <dtmrpy.dtmrpy.DT_GMM object at 0x000001686437...
# 354  <dtmrpy.dtmrpy.DT_GMM object at 0x000001686437...
#
# [355 rows x 26 columns]

# %%
tract = 'Cingulum_Frontal_Parahippocampal_L'

for i in range(50):
    if type(df.at[i,tract])==DT_GMM:
        plt.figure().add_subplot(projection = '3d')
        df.at[i,tract].plot()
        plt.title(df.at[i,'label'])
        plt.show()
# Out:
# C:\Users\micha\Documents\GitHub\Research\DTMRI\dtmrpy\dtmrpy.py:91: RuntimeWarning: invalid value encountered in divide
#   plt.plot(x,y,z,'.',c=rgb/sum(rgb), alpha = w[i][0])
